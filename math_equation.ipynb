# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
K = 10 
x_values = np.linspace(1, 10, 500)
y_values = K / x_values

# %%
plt.plot(x_values, y_values, label=f'x*y = {K}')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
